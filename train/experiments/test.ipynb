# %%
import numpy as np
times = np.array([1.176002,
1.156639,
1.130812,
1.192015,
1.251441,
1.109133,
1.138580,
1.150744
])
print("Mean time ResNet18:", np.mean(times))
# Out:
# Mean time ResNet18: 1.16317075

# %%
times = np.array([1.798455,
1.696924,
1.706208,
1.704347])
print("Mean time MLP:", np.mean(times))
# Out:
# Mean time MLP: 1.7264835
